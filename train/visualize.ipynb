# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

# 제공된 데이터를 문자열로 저장합니다.
data_string = """
Baseline                    : MRR = 0.5605 | Success@1 = 0.3585 | Success@3 = 0.7075
Weighted (Full)             : MRR = 0.5619 | Success@1 = 0.3600 | Success@3 = 0.7096
Top-10 (Sparse)             : MRR = 0.3912 | Success@1 = 0.1751 | Success@3 = 0.4729
Top-10 (Weighted Sparse)    : MRR = 0.3912 | Success@1 = 0.1751 | Success@3 = 0.4729
Top-10 (Variance)           : MRR = 0.4815 | Success@1 = 0.2685 | Success@3 = 0.6018
Top-10 (Variance x Weight)  : MRR = 0.4830 | Success@1 = 0.2704 | Success@3 = 0.6031
Top-20 (Sparse)             : MRR = 0.4240 | Success@1 = 0.2095 | Success@3 = 0.5199
Top-20 (Weighted Sparse)    : MRR = 0.4240 | Success@1 = 0.2095 | Success@3 = 0.5199
Top-20 (Variance)           : MRR = 0.5047 | Success@1 = 0.2946 | Success@3 = 0.6344
Top-20 (Variance x Weight)  : MRR = 0.5054 | Success@1 = 0.2948 | Success@3 = 0.6388
Top-30 (Sparse)             : MRR = 0.4382 | Success@1 = 0.2226 | Success@3 = 0.5426
Top-30 (Weighted Sparse)    : MRR = 0.4382 | Success@1 = 0.2226 | Success@3 = 0.5426
Top-30 (Variance)           : MRR = 0.5168 | Success@1 = 0.3102 | Success@3 = 0.6489
Top-30 (Variance x Weight)  : MRR = 0.5187 | Success@1 = 0.3120 | Success@3 = 0.6519
Top-100 (Sparse)            : MRR = 0.4982 | Success@1 = 0.2879 | Success@3 = 0.6250
Top-100 (Weighted Sparse)   : MRR = 0.4982 | Success@1 = 0.2879 | Success@3 = 0.6250
Top-100 (Variance)          : MRR = 0.5356 | Success@1 = 0.3301 | Success@3 = 0.6744
Top-100 (Variance x Weight) : MRR = 0.5356 | Success@1 = 0.3293 | Success@3 = 0.6760
Top-200 (Sparse)            : MRR = 0.5233 | Success@1 = 0.3140 | Success@3 = 0.6622
Top-200 (Weighted Sparse)   : MRR = 0.5233 | Success@1 = 0.3140 | Success@3 = 0.6622
Top-200 (Variance)          : MRR = 0.5454 | Success@1 = 0.3411 | Success@3 = 0.6866
Top-200 (Variance x Weight) : MRR = 0.5460 | Success@1 = 0.3418 | Success@3 = 0.6871
Top-300 (Sparse)            : MRR = 0.5366 | Success@1 = 0.3280 | Success@3 = 0.6815
Top-300 (Weighted Sparse)   : MRR = 0.5366 | Success@1 = 0.3280 | Success@3 = 0.6815
Top-300 (Variance)          : MRR = 0.5491 | Success@1 = 0.3451 | Success@3 = 0.6927
Top-300 (Variance x Weight) : MRR = 0.5498 | Success@1 = 0.3454 | Success@3 = 0.6934
Top-400 (Sparse)            : MRR = 0.5472 | Success@1 = 0.3430 | Success@3 = 0.6894
Top-400 (Weighted Sparse)   : MRR = 0.5472 | Success@1 = 0.3430 | Success@3 = 0.6894
Top-400 (Variance)          : MRR = 0.5507 | Success@1 = 0.3464 | Success@3 = 0.6932
Top-400 (Variance x Weight) : MRR = 0.5515 | Success@1 = 0.3469 | Success@3 = 0.6960
Top-500 (Sparse)            : MRR = 0.5496 | Success@1 = 0.3443 | Success@3 = 0.6946
Top-500 (Weighted Sparse)   : MRR = 0.5496 | Success@1 = 0.3443 | Success@3 = 0.6946
Top-500 (Variance)          : MRR = 0.5549 | Success@1 = 0.3523 | Success@3 = 0.6988
Top-500 (Variance x Weight) : MRR = 0.5530 | Success@1 = 0.3484 | Success@3 = 0.6991
Top-600 (Sparse)            : MRR = 0.5532 | Success@1 = 0.3497 | Success@3 = 0.6971
Top-600 (Weighted Sparse)   : MRR = 0.5532 | Success@1 = 0.3498 | Success@3 = 0.6971
Top-600 (Variance)          : MRR = 0.5545 | Success@1 = 0.3519 | Success@3 = 0.6985
Top-600 (Variance x Weight) : MRR = 0.5554 | Success@1 = 0.3519 | Success@3 = 0.7023
Top-700 (Sparse)            : MRR = 0.5562 | Success@1 = 0.3534 | Success@3 = 0.6989
Top-700 (Weighted Sparse)   : MRR = 0.5563 | Success@1 = 0.3535 | Success@3 = 0.6989
Top-700 (Variance)          : MRR = 0.5547 | Success@1 = 0.3512 | Success@3 = 0.7005
Top-700 (Variance x Weight) : MRR = 0.5582 | Success@1 = 0.3562 | Success@3 = 0.7034
Top-800 (Sparse)            : MRR = 0.5590 | Success@1 = 0.3574 | Success@3 = 0.7013
Top-800 (Weighted Sparse)   : MRR = 0.5591 | Success@1 = 0.3574 | Success@3 = 0.7018
Top-800 (Variance)          : MRR = 0.5568 | Success@1 = 0.3535 | Success@3 = 0.7041
Top-800 (Variance x Weight) : MRR = 0.5590 | Success@1 = 0.3573 | Success@3 = 0.7050
Top-900 (Sparse)            : MRR = 0.5598 | Success@1 = 0.3574 | Success@3 = 0.7054
Top-900 (Weighted Sparse)   : MRR = 0.5599 | Success@1 = 0.3574 | Success@3 = 0.7054
Top-900 (Variance)          : MRR = 0.5577 | Success@1 = 0.3542 | Success@3 = 0.7060
Top-900 (Variance x Weight) : MRR = 0.5594 | Success@1 = 0.3561 | Success@3 = 0.7062
Top-1000 (Sparse)           : MRR = 0.5621 | Success@1 = 0.3602 | Success@3 = 0.7089
Top-1000 (Weighted Sparse)  : MRR = 0.5625 | Success@1 = 0.3612 | Success@3 = 0.7092
Top-1000 (Variance)         : MRR = 0.5599 | Success@1 = 0.3575 | Success@3 = 0.7066
Top-1000 (Variance x Weight): MRR = 0.5612 | Success@1 = 0.3587 | Success@3 = 0.7092
"""

# 데이터를 줄 단위로 분리하고 파싱하여 리스트에 저장합니다.
lines = data_string.strip().split('\n')
data = []
for line in lines:
    parts = line.split(':')
    model_info = parts[0].strip()
    metrics = parts[1].strip()

    # 정규 표현식을 사용하여 각 메트릭 값을 추출합니다.
    mrr = float(re.search(r'MRR = ([\d.]+)', metrics).group(1))
    success1 = float(re.search(r'Success@1 = ([\d.]+)', metrics).group(1))
    success3 = float(re.search(r'Success@3 = ([\d.]+)', metrics).group(1))

    if 'Top' in model_info:
        # Top-k 모델의 경우 차원 크기와 타입을 추출합니다.
        size_match = re.search(r'Top-(\d+)', model_info)
        dimension_size = int(size_match.group(1)) if size_match else None
        model_type_match = re.search(r'\((.*?)\)', model_info)
        model_type = model_type_match.group(1) if model_type_match else None
        data.append([model_type, dimension_size, mrr, success1, success3])
    else:
        # Baseline과 Weighted (Full) 모델의 경우
        data.append([model_info, None, mrr, success1, success3])

# 파싱된 데이터를 Pandas DataFrame으로 변환합니다.
df = pd.DataFrame(data, columns=['Type', 'Dimension', 'MRR', 'Success@1', 'Success@3'])

# 기준선이 되는 모델들을 분리합니다.
baseline = df[df['Type'] == 'Baseline']
weighted_full = df[df['Type'] == 'Weighted (Full)']
top_k_data = df.dropna(subset=['Dimension'])

# 그래프를 그리기 쉽게 데이터를 피벗(pivot)합니다.
pivot_mrr = top_k_data.pivot(index='Dimension', columns='Type', values='MRR')
pivot_s1 = top_k_data.pivot(index='Dimension', columns='Type', values='Success@1')
pivot_s3 = top_k_data.pivot(index='Dimension', columns='Type', values='Success@3')

# 각 메트릭에 대한 그래프를 생성합니다.
metrics_to_plot = [('MRR', pivot_mrr), ('Success@1', pivot_s1), ('Success@3', pivot_s3)]
markers = {'Sparse': 'o', 'Weighted Sparse': 's', 'Variance': '^'}

for metric, pivot_df in metrics_to_plot:
    plt.figure(figsize=(12, 7))
    # Top-k 모델들의 꺾은선 그래프를 그립니다.
    for model_type in pivot_df.columns:
        plt.plot(pivot_df.index, pivot_df[model_type], marker=markers.get(model_type, 'x'), linestyle='-', label=f'Top-k ({model_type})')

    # Baseline과 Weighted (Full) 모델의 가로선을 추가합니다.
    plt.axhline(y=baseline[metric].iloc[0], color='r', linestyle='--', label=f'Baseline ({baseline[metric].iloc[0]:.4f})')
    plt.axhline(y=weighted_full[metric].iloc[0], color='g', linestyle=':', label=f'Weighted (Full) ({weighted_full[metric].iloc[0]:.4f})')

    # 그래프 제목 및 라벨을 설정합니다.
    plt.title(f'{metric} vs. Dimension Size', fontsize=16)
    plt.xlabel('Dimension Size (k)', fontsize=12)
    plt.ylabel(metric, fontsize=12)
    plt.legend(title='Method')
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)
    plt.xticks(pivot_df.index)
    plt.tight_layout()
    
    # 그래프를 이미지 파일로 저장합니다.
    plt.savefig(f'visualization_{metric}.png')
    plt.close()

print("그래프가 성공적으로 파일로 저장되었습니다.")
# Out:
# 그래프가 성공적으로 파일로 저장되었습니다.
